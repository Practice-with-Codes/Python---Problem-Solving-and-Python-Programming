# %% [markdown]
# # Function With More Than One Return Value

# %%
# function with multiple return values

def calculate(number1, number2):
    addition = number1 + number2
    subtraction = number1 - number2
    multiplication = number1 * number2
    division = number1 / number2
    return addition, subtraction, multiplication, division
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number: "))
a, s, m, d = calculate(number1, number2)
print("Addition: ", a)
print("Subtraction: ", s)
print("Multiplication: ", m)
print("Division: ", d)
# Out:
# Enter the first number:2
# Enter the second number: 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de67208232b9> in <module>
#       9 num1 = int(input("Enter the first number:"))
#      10 num2 = int(input("Enter the second number: "))
# ---> 11 a, s, m, d = calculate(number1, number2)
#      12 print("Addition: ", a)
#      13 print("Subtraction: ", s)
#
# NameError: name 'number1' is not defined
