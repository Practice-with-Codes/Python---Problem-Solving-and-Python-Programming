# %% [markdown]
# # AD__17: Compare and return two different list and return True if they contain one common value

# %%
def common_data(list_one, list_two):
    result = False
    for number1 in list_one:
        for number2 in list_two:
            if number1 == number2:
                final_result = True
                return final_result
# Main Program
list_one = input("Enter the first list(space seperated): ")
list_one = list(list_one.split())
list_two = input("Enter the two list(space seperated): ")
list_two = list(list_two.split())
r = common_data(list_one, list_two)
if r:
    print(list_one, "and", list_two, "has atleast commmon member: ", r)
else:
    print(list_one, "and", list_two, "has atleast commmon member: ", r)
# Out:
# Enter the first list(space seperated): hai hello 8
# Enter the two list(space seperated): hai good morning
# ['hai', 'hello', '8'] and ['hai', 'good', 'morning'] has atleast commmon member:  True
